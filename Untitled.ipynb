# %%
pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U pip setuptools wheel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/15/aa/3f4c7bcee2057a76562a5b33ecbd199be08cdb4443a02e26bd2c3cf6fc39/pip-23.3.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/55/3a/5121b58b578a598b269537e09a316ad2a94fdd561a2c6eb75cd68578cc6b/setuptools-69.0.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/c7/c3/55076fc728723ef927521abaa1955213d094933dc36d4a2008d5101e1af5/wheel-0.42.0-py3-none-any.whl.metadata
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 660.6 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.3/2.1 MB 3.2 MB/s eta 0:00:01
# ...

# %%
# %pip install -U spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 165.2 kB/s eta 0:01:18
#      --------------------------------------- 0.0/12.8 MB 217.9 kB/s eta 0:00:59
#      --------------------------------------- 0.1/12.8 MB 363.1 kB/s eta 0:00:36
#      - -------------------------------------- 0.4/12.8 MB 1.8 MB/s eta 0:00:07
#      -- ------------------------------------- 0.9/12.8 MB 3.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.4/12.8 MB 4.6 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.8/12.8 MB 5.2 MB/s eta 0:00:03
#      ------ --------------------------------- 2.1/12.8 MB 5.2 MB/s eta 0:00:03
#      ------- -------------------------------- 2.3/12.8 MB 5.1 MB/s eta 0:00:03
# ...

# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/636.8 kB ? eta -:--:--
#       --------------------------------------- 10.2/636.8 kB ? eta -:--:--
#      -- ---------------------------------- 51.2/636.8 kB 525.1 kB/s eta 0:00:02
#      ------------------ ------------------- 317.4/636.8 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------- 636.8/636.8 kB 3.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

# %%
df =pd.read_csv('C:\\Users\\hp\\Documents\\tsa\\twitter_sentiment.csv' ,header=None , index_col=0)

# %%
df.head()
# Out:
#                 1         2                                                  3
# 0
# 2401  Borderlands  Positive  im getting on borderlands and i will murder yo...
# 2401  Borderlands  Positive  I am coming to the borders and I will kill you...
# 2401  Borderlands  Positive  im getting on borderlands and i will kill you ...
# 2401  Borderlands  Positive  im coming on borderlands and i will murder you...
# 2401  Borderlands  Positive  im getting on borderlands 2 and i will murder ...

# %%
df =df[[2,3]].reset_index(drop=True)

# %%
df
# Out:
#                 2                                                  3
# 0        Positive  im getting on borderlands and i will murder yo...
# 1        Positive  I am coming to the borders and I will kill you...
# 2        Positive  im getting on borderlands and i will kill you ...
# 3        Positive  im coming on borderlands and i will murder you...
# 4        Positive  im getting on borderlands 2 and i will murder ...
# ...           ...                                                ...
# 75677  Irrelevant  ⭐️ Toronto is the arts and culture capital of ...
# 75678  Irrelevant  tHIS IS ACTUALLY A GOOD MOVE TOT BRING MORE VI...
# 75679    Positive  Today sucked so it’s time to drink wine n play...
# 75680    Positive  Bought a fraction of Microsoft today. Small wins.
# 75681     Neutral  Johnson & Johnson to stop selling talc baby po...
#
# [75682 rows x 2 columns]

# %%
df.columns=['sentiment' , 'text']
df.head(3)
# Out:
#   sentiment                                               text
# 0  Positive  im getting on borderlands and i will murder yo...
# 1  Positive  I am coming to the borders and I will kill you...
# 2  Positive  im getting on borderlands and i will kill you ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75682 entries, 0 to 75681
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  75682 non-null  object
#  1   text       74996 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
df.isnull().sum()
# Out:
# sentiment      0
# text         686
# dtype: int64

# %%
df.sample(10)
# Out:
#         sentiment                                               text
# 12049    Positive                                      That's great.
# 46924     Neutral  An employee at the Pasadena Girls Home Depot h...
# 70719    Positive       I appreciate how my sniper flies on the roof
# 31330     Neutral                            ... Check out my video!
# 6662   Irrelevant  Hey, that's great!!. I wanted to do it on the ...
# 27717    Positive                         Itching will assassinate..
# 44059    Negative  PUBG for PC awein took the beatings. Children ...
# 26719     Neutral  Back to ancient Greece with the murderers "ody...
# 20349    Negative  Warcraft 3 Reforged released and was met with ...
# 67234    Negative  Why was getting this shit still on the market?...

# %%
df.dropna(inplace=True)

# %%
df['text'].apply(len)
# Out:
# 0         53
# 1         51
# 2         50
# 3         51
# 4         57
#         ...
# 75677    281
# 75678    248
# 75679    120
# 75680     49
# 75681    116
# Name: text, Length: 74996, dtype: int64

# %%
#searching for values less than 10
df['text'].apply(len).value_counts()
# Out:
# text
# 70     611
# 3      566
# 2      500
# 36     485
# 57     480
#       ...
# 418      1
# 434      1
# 394      1
# 427      1
# 374      1
# Name: count, Length: 403, dtype: int64

# %%
df['text'].apply(len)>5
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 75677    True
# 75678    True
# 75679    True
# 75680    True
# 75681    True
# Name: text, Length: 74996, dtype: bool

# %%
sum(df['text'].apply(len)>5)
# Out:
# 72883

# %%
sum(df['text'].apply(len)<=5)
# Out:
# 2113

# %%
#filter out these 2113 data

# %%
print(df.shape)
df=df[df['text'].apply(len)>5]
print(df.shape)
# Out:
# (74996, 2)
# (72883, 2)

# %%
df.sample(10)
# Out:
#       sentiment                                               text
# 47695  Negative  @ HomeDepot delivery scheduled today for onlin...
# 72505   Neutral  Amazing offer for you!.. Lenovo Legion Y540 9t...
# 36357  Negative  It’s wild Halo 2 featured the best video game ...
# 38023  Positive  OMG! I finally broke my super long Hearthstone...
# 71031   Neutral                                      .. Those say.
# 2092   Negative  I HATE borderlands 3 Rhys WHY heck does he alm...
# 48007  Positive                            Wow! Incredible to see.
# 14311  Negative  @ dota2 quarantine has fucked all dota players...
# 48924  Negative  i used to work at home depot and all i can say...
# 63234  Negative                    @EAMaddenNFL  this games ass .

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Negative      22020
# Positive      20186
# Neutral       17899
# Irrelevant    12778
# Name: count, dtype: int64

# %%
pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to c:\users\hp\appdata\local\temp\pip-req-build-b5ibnnfk
#   Resolved https://github.com/laxmimerit/preprocess_kgptalkie.git to commit 96bf02872d9756f29d6cddb8aafaedcd2a39bbb4
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for preprocess_kgptalkie: filename=preprocess_kgptalkie-0.1.3-py3-none-any.whl size=7665 sha256=118b84b93abae8199ff1667a4101eb4c25e0e9a25eb3b97bfa28e01aacbb44fe
#   Stored in directory: C:\Users\hp\AppData\Local\Temp\pip-ephem-wheel-cache-wkrmebw4\wheels\74\fe\05\0d013c54ae5e4afb77c6c480378063827c84f57ea5f554e072
# Successfully built preprocess_kgptalkie
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
conda install git
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - git
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     git-2.40.1                 |       haa95532_1        69.2 MB
#     ------------------------------------------------------------
#                                            Total:        69.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   git                pkgs/main/win-64::git-2.40.1-haa95532_1
#
#
#
# ...
#
# git-2.40.1           | 69.2 MB   |            |   0%
# git-2.40.1           | 69.2 MB   |            |   0%
# git-2.40.1           | 69.2 MB   | 1          |   1%
# git-2.40.1           | 69.2 MB   | 2          |   2%
# git-2.40.1           | 69.2 MB   | 3          |   4%
# ...

# %%
import preprocess_kgptalkie as ps

# %%
df.head()
# Out:
#   sentiment                                               text
# 0  Positive  im getting on borderlands and i will murder yo...
# 1  Positive  I am coming to the borders and I will kill you...
# 2  Positive  im getting on borderlands and i will kill you ...
# 3  Positive  im coming on borderlands and i will murder you...
# 4  Positive  im getting on borderlands 2 and i will murder ...

# %%
df.columns
# Out:
# Index(['sentiment', 'text'], dtype='object')

# %%
df =ps.get_basic_features(df)

# %%
df.columns
# Out:
# Index(['sentiment', 'text', 'char_counts', 'word_counts', 'avg_wordlength',
#        'stopwords_counts', 'hashtag_counts', 'mentions_counts',
#        'digits_counts', 'uppercase_counts'],
#       dtype='object')

# %%
df.head()
# Out:
#   sentiment                                               text  char_counts  \
# 0  Positive  im getting on borderlands and i will murder yo...           43
# 1  Positive  I am coming to the borders and I will kill you...           40
# 2  Positive  im getting on borderlands and i will kill you ...           41
# 3  Positive  im coming on borderlands and i will murder you...           42
# 4  Positive  im getting on borderlands 2 and i will murder ...           46
#
#    word_counts  avg_wordlength  stopwords_counts  hashtag_counts  \
# 0           11        3.909091                 6               0
# 1           12        3.333333                 6               0
# 2           10        4.100000                 5               0
# 3           10        4.200000                 5               0
# 4           12        3.833333                 6               0
#
#    mentions_counts  digits_counts  uppercase_counts
# 0                0              1                 0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
num_cols=df.select_dtypes(include='number').columns

for index, col in enumerate(num_cols):
    plt.subplot(2,4, index+1)
    sns.kdeplot(data=df,x=col ,hue="sentiment" , fill=False)
    
plt.tight_layout()
plt.show()

# %%
df.select_dtypes(include='number')
# Out:
#        char_counts  word_counts  avg_wordlength  stopwords_counts  \
# 0               43           11        3.909091                 6
# 1               40           12        3.333333                 6
# 2               41           10        4.100000                 5
# 3               42           10        4.200000                 5
# 4               46           12        3.833333                 6
# ...            ...          ...             ...               ...
# 75677          235           47        5.000000                20
# 75678          202           46        4.391304                15
# 75679           97           24        4.041667                 9
# 75680           42            8        5.250000                 2
# 75681          101           16        6.312500                 3
#
#        hashtag_counts  mentions_counts  digits_counts  uppercase_counts
# 0                   0                0              1                 0
# ...

# %%
df['sentiment'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          Positive
# 1          Positive
# 2          Positive
# 3          Positive
# 4          Positive
#             ...
# 75677    Irrelevant
# 75678    Irrelevant
# 75679      Positive
# 75680      Positive
# 75681       Neutral
# Name: sentiment, Length: 72883, dtype: object>

# %%
df['sentiment'].value_counts().plot(kind='pie' , autopct="%1.0f%%")
# Out:
# <Axes: ylabel='count'>

# %%
##word count

# %%
pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/300.2 kB 435.7 kB/s eta 0:00:01
#    --------------- ------------------------ 112.6/300.2 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  297.0/300.2 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 1.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\hp\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from wordcloud import WordCloud , STOPWORDS

# %%
stopwords=set(STOPWORDS)

# %%
wordcloud = WordCloud(background_color='white' ,stopwords=stopwords,max_words=300,max_font_size=40,scale=5).generate(str(df['text']))

plt.imshow(wordcloud)

# %%
plt.figure(figsize=(40,20))

for index ,sent in enumerate(df['sentiment'].unique()):
    plt.subplot(2,2, index+1)
    
    data=df[df['sentiment']==sent]['text']
    wordcloud = WordCloud(background_color='white' ,stopwords=stopwords,max_words=300,max_font_size=40,scale=5).generate(str(data))
    
    plt.imshow( wordcloud)
    plt.xticks([])
    plt.yticks([])
    plt.title(sent, fontsize=40)

# %%
##data cleaning

# %%
df['text']=df['text'].apply(lambda x:x.lower())

# %%
df['text']=df['text'].apply(lambda x:ps.remove_urls(x))

# %%
df['text']=df['text'].apply(lambda x:ps.remove_html_tags(x))

# %%
df['text']=df['text'].apply(lambda x:ps.remove_rt(x))

# %%
df['text']=df['text'].apply(lambda x:ps.remove_special_chars(x))

# %%
##train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test , y_train, y_test=train_test_split(df['text'],
                                                   df['sentiment'],
                                                  test_size=0.2,
                                                  random_state=0)

# %%
X_train.shape , X_test.shape
# Out:
# ((58306,), (14577,))

# %%
##model

# %%
# !pip install scikit-learn==0.13
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB 487.6 kB/s eta 0:00:08
#      - -------------------------------------- 0.2/3.5 MB 1.2 MB/s eta 0:00:03
#      -- ------------------------------------- 0.2/3.5 MB 1.4 MB/s eta 0:00:03
#      -- ------------------------------------- 0.3/3.5 MB 1.3 MB/s eta 0:00:03
#      --- ------------------------------------ 0.3/3.5 MB 1.1 MB/s eta 0:00:03
#      --- ------------------------------------ 0.3/3.5 MB 980.4 kB/s eta 0:00:04
#      --- ------------------------------------ 0.3/3.5 MB 922.8 kB/s eta 0:00:04
#      ---- ----------------------------------- 0.4/3.5 MB 855.4 kB/s eta 0:00:04
# ...

# %%
pip install pipwin
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      -- ------------------------------------- 0.1/1.0 MB 975.2 kB/s eta 0:00:01
#      --- ------------------------------------ 0.1/1.0 MB 871.5 kB/s eta 0:00:02
#      --- ------------------------------------ 0.1/1.0 MB 871.5 kB/s eta 0:00:02
#      --- ------------------------------------ 0.1/1.0 MB 871.5 kB/s eta 0:00:02
#      ---- ----------------------------------- 0.1/1.0 MB 467.6 kB/s eta 0:00:02
#      ---- ----------------------------------- 0.1/1.0 MB 379.3 kB/s eta 0:00:03
# ...

# %%
pip install wheel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update conda
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiobotocore-2.7.0          |  py311haa95532_0         153 KB
#     aiohttp-3.9.0              |  py311h2bbff1b_0         773 KB
#     anaconda-cloud-auth-0.1.4  |  py311haa95532_0          39 KB
#     archspec-0.2.1             |     pyhd3eb1b0_0          39 KB
#     astropy-5.3.4              |  py311hd7041d2_0         9.7 MB
#     async-lru-2.0.4            |  py311haa95532_0          21 KB
#     attrs-23.1.0               |  py311haa95532_0         165 KB
#     black-23.11.0              |  py311haa95532_0         382 KB
#     bokeh-3.3.0                |  py311h746a85d_0         5.7 MB
#     boost-cpp-1.82.0           |       h59b6b97_2          11 KB
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
clf=Pipeline([('tfid' ,TfidfVectorizer()),
             ('rfc' , RandomForestClassifier(n_jobs=-1))])

# %%
clf.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('tfid', TfidfVectorizer()),
#                 ('rfc', RandomForestClassifier(n_jobs=-1))])

# %%
#evaluation

# %%
from sklearn.metrics import classification_report

# %%
y_pred =clf.predict(X_test)

# %%
print(classification_report(y_test ,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   Irrelevant       0.98      0.85      0.91      2561
#     Negative       0.91      0.95      0.93      4481
#      Neutral       0.92      0.91      0.92      3553
#     Positive       0.91      0.94      0.92      3982
#
#     accuracy                           0.92     14577
#    macro avg       0.93      0.92      0.92     14577
# weighted avg       0.92      0.92      0.92     14577

# %%
import pickle

# %%
pickle.dump(clf,open("twitter_sentiment.pkl" ,'wb'))

# %%
clf.predict(['let me not upset you'])
# Out:
# array(['Negative'], dtype=object)

# %%
clf.predict(['hello good day to you sir'])
# Out:
# array(['Positive'], dtype=object)

# %%
clf.predict(['you did well'])
# Out:
# array(['Positive'], dtype=object)

# %%
clf.predict(['here a gift for you'])
# Out:
# array(['Irrelevant'], dtype=object)

# %%
clf.predict(['thanks'])
# Out:
# array(['Positive'], dtype=object)

# %%
clf.predict(['welcome'])
# Out:
# array(['Irrelevant'], dtype=object)

# %%
clf.predict(['dumb'])
# Out:
# array(['Negative'], dtype=object)

# %%
clf.predict(['i hit rock hard'])
# Out:
# array(['Neutral'], dtype=object)

# %%
clf.predict(['The 𝐟𝐢𝐫𝐬𝐭 𝐧𝐚𝐭𝐢𝐨𝐧 to reach the lunar south pole.That got a nice ring to itA proud moment for each one of us & a big congratulations to @isro for all their efforts.'])
# Out:
# array(['Positive'], dtype=object)
